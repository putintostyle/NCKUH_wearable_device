# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('116_medians.csv', header = None)

# %%
df[0] = [datetime.datetime.strptime(i, '%Y-%m-%d').date() for i in df[0].values]
date_list = np.sort(list(dict.fromkeys(df[0].values)))
time_list = np.array(np.arange(0, 28), dtype = int)
Q1 = df[2].values
median = df[3].values
Q3 = df[4].values

# %%
ear_df = pd.read_csv('eartmp.csv', header = None)
ear_df[0] = [datetime.datetime.strptime(i, '%Y-%m-%d').date() for i in ear_df[0].values]
ear_df[1] = [datetime.datetime.strptime(i, '%H:%M').time() for i in ear_df[1].values]
ear_df[1] = [np.floor((datetime.datetime.combine((ear_df[0].values)[i], (ear_df[1].values)[i])-datetime.datetime.combine((ear_df[0].values)[i], datetime.time(8,0)))/datetime.timedelta(minutes = 30)) for i in range(len(ear_df[0].values))]
ear_date = np.sort(list(dict.fromkeys(ear_df[0].values)))
ear_time = ear_df[1].values
ear_temp = ear_df[2].values

# %%
ear_filter = (ear_temp>37.5)&(ear_time<=28)
risk_array = [(ear_df[0].values)[ear_filter], ear_time[ear_filter], ear_temp[ear_filter]]

# %%
risk_array
# Out:
# [array([datetime.date(2020, 1, 24), datetime.date(2020, 1, 25),
#         datetime.date(2020, 1, 26)], dtype=object),
#  array([ 2., 25., 10.]),
#  array([38.1, 38.6, 37.8])]

# %%
for date in range(len(date_list)):
    d_filter = time_list+28*(date)
    
    daily_Q1 = Q1[d_filter]
    daily_Q3 = Q3[d_filter]
    daily_median = median[d_filter]
    
    ear_daily_filter = (risk_array[0] == date_list[date])
    for i in range(len(risk_array[1][ear_daily_filter])):
        print((risk_array[1][ear_daily_filter])[i],(risk_array[2][ear_daily_filter])[i])
        plt.scatter((risk_array[1][ear_daily_filter])[i],(risk_array[2][ear_daily_filter])[i])
        
    
    plt.plot( time_list+1, daily_Q1)
    plt.plot( time_list+1, daily_Q3)
    plt.plot( time_list+1, daily_median)
    plt.xticks(time_list+1)
    plt.show()
# Out:
# 2.0 38.1
# 25.0 38.6
# 10.0 37.8

# %%
d_Q1 [20:25]
# Out:
# array([33.7075, 34.78  , 35.2075, 35.3375, 34.3575])

# %%
data_filter = date_list[1:3]
# find_increasing_interval(Q1[time_list+28*(2)], time_list)
for day in range(2,3):
    d_Q1 = Q1[time_list+28*(2)]
    d_Q3 = Q3[time_list+28*(2)]
    d_med = median[time_list+28*(2)]
    target = risk_array[1][risk_array[0] == date_list[day]] # time
    
    classify_result = []
    temp_cri_list = np.linspace(32, 36, 11)
     
    for time_cri in range(2,8):
        for temp_cri in temp_cri_list:
            TP = 0
            TN = 0
            FP = 0
            FN = 0
            for time in time_list:
                print()
                if time >= time_cri:
                    diagonis = upper_identify(d_Q1[time-time_cri:time], temp_cri) & increasing_identify((d_Q1[time-time_cri:time] > temp_cri))
                    if (diagonis == True) & (time in target):
                        
                        TP += 1
                    elif (diagonis == True) & (time not in target):
                        FP += 1
                    elif (diagonis == False) & (time in target):
                        TN += 1
                    elif (diagonis == False) & (time not in target):
                        FN += 1
            TPR = TP / (TP+FN)
            FPR = FP / (FP + TN)
            ACC = (TP + TN) / ((TP+FN) + (FP + TN))
            c = [time_cri, temp_cri]
            classify_result.append([round(TPR,2), round(FPR,2), round(ACC,2), round(np.sqrt((TPR-1)**2+FPR**2),2), c])

# %%
classify_result
# Out:
# [[0.0, 0.0, 0.04, 1.0, [2, 32.0]],
#  [0.0, 0.0, 0.04, 1.0, [2, 32.4]],
#  [0.0, 0.0, 0.04, 1.0, [2, 32.8]],
#  [0.0, 0.0, 0.04, 1.0, [2, 33.2]],
#  [0.0, 0.0, 0.04, 1.0, [2, 33.6]],
#  [0.0, 0.0, 0.04, 1.0, [2, 34.0]],
#  [0.0, 0.0, 0.04, 1.0, [2, 34.4]],
#  [0.0, 0.0, 0.04, 1.0, [2, 34.8]],
#  [0.0, 0.0, 0.04, 1.0, [2, 35.2]],
#  [0.0, 0.0, 0.04, 1.0, [2, 35.6]],
#  [0.0, 0.0, 0.04, 1.0, [2, 36.0]],
#  [0.0, 0.0, 0.04, 1.0, [3, 32.0]],
#  [0.0, 0.67, 0.04, 1.2, [3, 32.4]],
#  [0.0, 0.67, 0.04, 1.2, [3, 32.8]],
#  [0.0, 0.67, 0.04, 1.2, [3, 33.2]],
#  [0.0, 0.83, 0.04, 1.3, [3, 33.6]],
#  [0.0, 0.75, 0.04, 1.25, [3, 34.0]],
#  [0.0, 0.67, 0.04, 1.2, [3, 34.4]],
#  [0.0, 0.5, 0.04, 1.12, [3, 34.8]],
#  [0.0, 0.5, 0.04, 1.12, [3, 35.2]],
#  [0.0, 0.0, 0.04, 1.0, [3, 35.6]],
#  [0.0, 0.0, 0.04, 1.0, [3, 36.0]],
#  [0.0, 0.0, 0.04, 1.0, [4, 32.0]],
#  [0.0, 0.0, 0.04, 1.0, [4, 32.4]],
#  [0.0, 0.0, 0.04, 1.0, [4, 32.8]],
#  [0.0, 0.0, 0.04, 1.0, [4, 33.2]],
#  [0.0, 0.0, 0.04, 1.0, [4, 33.6]],
#  [0.0, 0.0, 0.04, 1.0, [4, 34.0]],
#  [0.0, 0.0, 0.04, 1.0, [4, 34.4]],
#  [0.0, 0.0, 0.04, 1.0, [4, 34.8]],
#  [0.0, 0.0, 0.04, 1.0, [4, 35.2]],
#  [0.0, 0.0, 0.04, 1.0, [4, 35.6]],
#  [0.0, 0.0, 0.04, 1.0, [4, 36.0]],
#  [0.0, 0.0, 0.04, 1.0, [5, 32.0]],
#  [0.0, 0.0, 0.04, 1.0, [5, 32.4]],
#  [0.0, 0.0, 0.04, 1.0, [5, 32.8]],
#  [0.0, 0.0, 0.04, 1.0, [5, 33.2]],
#  [0.0, 0.0, 0.04, 1.0, [5, 33.6]],
#  [0.0, 0.0, 0.04, 1.0, [5, 34.0]],
#  [0.0, 0.0, 0.04, 1.0, [5, 34.4]],
#  [0.0, 0.0, 0.04, 1.0, [5, 34.8]],
#  [0.0, 0.0, 0.04, 1.0, [5, 35.2]],
#  [0.0, 0.0, 0.04, 1.0, [5, 35.6]],
#  [0.0, 0.0, 0.04, 1.0, [5, 36.0]],
#  [0.0, 0.0, 0.05, 1.0, [6, 32.0]],
#  [0.0, 0.0, 0.05, 1.0, [6, 32.4]],
#  [0.0, 0.0, 0.05, 1.0, [6, 32.8]],
#  [0.0, 0.0, 0.05, 1.0, [6, 33.2]],
#  [0.0, 0.0, 0.05, 1.0, [6, 33.6]],
#  [0.0, 0.0, 0.05, 1.0, [6, 34.0]],
#  [0.0, 0.0, 0.05, 1.0, [6, 34.4]],
#  [0.0, 0.0, 0.05, 1.0, [6, 34.8]],
#  [0.0, 0.0, 0.05, 1.0, [6, 35.2]],
#  [0.0, 0.0, 0.05, 1.0, [6, 35.6]],
#  [0.0, 0.0, 0.05, 1.0, [6, 36.0]],
#  [0.0, 0.0, 0.05, 1.0, [7, 32.0]],
#  [0.0, 0.0, 0.05, 1.0, [7, 32.4]],
#  [0.0, 0.0, 0.05, 1.0, [7, 32.8]],
#  [0.0, 0.0, 0.05, 1.0, [7, 33.2]],
#  [0.0, 0.0, 0.05, 1.0, [7, 33.6]],
#  [0.0, 0.0, 0.05, 1.0, [7, 34.0]],
#  [0.0, 0.0, 0.05, 1.0, [7, 34.4]],
#  [0.0, 0.0, 0.05, 1.0, [7, 34.8]],
#  [0.0, 0.0, 0.05, 1.0, [7, 35.2]],
#  [0.0, 0.0, 0.05, 1.0, [7, 35.6]],
#  [0.0, 0.0, 0.05, 1.0, [7, 36.0]]]

# %%
Q1[time_list+28*(2)][0:9]
# Out:
# array([32.71  , 33.075 , 34.08  , 34.2   , 35.2875, 34.68  , 34.42  ,
#        33.66  , 33.3375])

# %%
def increasing_identify(data, r = 0.5):
    increasing = np.array([data[i+1]>data[i] for i in range(len(data)-1)], dtype = int)
#     print(increasing)
    if (np.sum(increasing) >= r*(len(data)-1)):
        return 1
    else:
        return 0
def upper_identify(data, cri, r = 0.5):
    upper = np.array(data>cri, dtype = int) 
    if (np.sum(upper) >= r*(len(data))):
        return 1
    else:
        return 0
# def find_increasing_interval(data, time):
#     interval = []
    
#     for data_idx in range(1,len(data)-1):
#         if len(interval) ==  0:
#             start = 0
#         if (data[data_idx+1] < data[data_idx]) & (time[data_idx]>start) & (data[data_idx-1] < data[data_idx]):
#             interval.append([start, time[data_idx]])
#         else:
#             continue
#         start = interval[-1][-1]+1 
#     return interval

# %%
# a = [1,2,3,4,5,2,3,5,2,1,1]
# increasing_identify(a)&upper_identify()
1&0
# Out:
# 0

# %%
upper_identify(np.linspace(32, 35, 16),34)
# Out:
# 0
